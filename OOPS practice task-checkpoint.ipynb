# %%
student1_name="soniya"
student1_add="vadapalani"
student1_phone=+908724
student1_age=28

# %%
student2_name="sassy"
student2_add="saligramam"
student2_phone=+99405135
student2_age=4

# %%
student2_name
# Out:
# 'sassy'

# %%
class student_information:

    def __init__(self,name,add,phone,age):
        self.name = name
        self.add = add
        self.phone = phone
        self.age = age


    def greet(self):
        print(self)
        print(f"hello {self.name}welcome to our dance classs at{self.add} contact{self.phone}and enter your{self.age} you are old")


    def i_age(self):
        self.age=self.age+10
        print(self.age)

# %%
student_1=student_information("soniya","vadapalani",+908724,28)

# %%
student_1.greet()
# Out:
# ...
# hello soniyawelcome to our dance classs atvadapalani contact908724and enter your28 you are old

# %%
student_2=student_information("sassy","saligramam",+994051,4)

# %%
student_3=student_information("luna","guindy",+889590,10)

# %%
student_3.greet()
# Out:
# ...
# hello lunawelcome to our dance classs atguindy contact889590and enter your10 you are old

# %% [markdown]
# # Object Oriented programming (OOP) is a programming paradigm that relies on the concept of classes and objects.

# %% [markdown]
# # TICKET APP

# %%
class ticket:


    def __init__(self,name,num_tickets,movie_name,age):
        self.name=name
        self.num_tickets=num_tickets
        self.movie_name=movie_name
        self.age=age


    def calculate_ticket_cost(self):
        print(3)

        if self.age<18:
           ticket_pric=100

        elif self.age>60:
           ticket_price=170

        else: 
           ticket_price=130


        total_price=ticket_price*num_tickets
        return total_price
        

      def Book_ticket(self):
          print(2)
          total_price=self.calculate_ticket_cost()


          print(f'thank you {self.name} you have booked {self.movie_name} ticket for{self.num_tickets}'):
          print(f'total amount is{total_price}Rs')
          
          
     

      if __name__=='__main___':
          print(1) 

          name=input("enter your name")
          age=int(input("enter your age"))
          num_tickets=int(input("enter the num of tickets"))
          movie_name=input("enter the movie name")


        
          customer=ticket(self,name,age,num_tickets,movie_name):
          customer.Book_ticket()
# Out:
#   File <string>:28
#     def Book_ticket(self):
#                           ^
# IndentationError: unindent does not match any outer indentation level

# %%
class software_emp:


      job_types="software"


      def __init__(self,name,emp_id,designation,sal,add,age):

          self.name=name
          self.emp_id=emp_id
          self.designation=designation
          self.__sal=sal #encapsulation
          self.age=age


          #getter
      def show_sal(self,password):
          if password=="@Lun566":
              print(f" Sal of {self.name} is {self.__sal}")
          else:
              print("Get lost")


           #setter
      def inc_sal(self,password):
          add_sal=20000
          if password=="@Lun566":
             print(f" sal of {self.name} is {self.__sal}")
                
          else:
              print("Get lost")

# %%
EMP_1=software_emp("soniya","007","DS",100000,"vadapalani",28)

# %%
EMP_1.age
# Out:
# 28

# %%
EMP_1.name
# Out:
# 'soniya'

# %%
EMP_1.emp_id
# Out:
# '007'

# %%
EMP_2=software_emp("sassy","005","DA", 200000,"saligramam",10)

# %%
EMP_2.designation
# Out:
# 'DA'

# %%
EMP_1.show_sal("@Lun566")
# Out:
#  Sal of soniya is 100000

# %%
EMP_1.show_sal("@LunA53r6")

# %%
EMP_1.age+20
# Out:
# 48

# %%
EMP_1.inc_sal("@Lun566")
# Out:
#  sal of soniya is 100000

# %%
EMP_1.job_types
# Out:
# 'software'

# %%
class software_emp:

         
    job_types="software"


      def __init__(self,name,emp_id,designation,sal,add,age):

          self.name=name
          self.emp_id=emp_id
          self.designation=designation
          self.__sal=sal #encapsulation
          self.add=add
          self.age=age


        # getter

      def show_sal(self,password):
          if password=="@Lun566":
              print(f" sal of {self.name} is {self.__sal}")
          
          else:
              print("Get lost")


        #setter
              
       def inc_sal(self,password):
           add_sal=20000
           if password=="@Lun566":
               self.__sal=self.__sal+add_sal
           
           else:
               print("Get lost")


class hardware_emp(software_emp):


    job_types="hardware"


      def __init__(self,name,emp_id,designation,sal,add,age,insur):
            software_emp:  __init__(self,name,emp_id<designation,sal,add,age):
            self.__sal=sal
            self.__insur=insur


      def inc_sal (self,password):
          add_sal=20000
          if  password=="@Lun566":
              self.__sal=self.__sal+20000
              self.__insur=self.__insur+20000
              print(self.__sal)
          
          else:
                ("Get lost")
        

     
                     
     def show_insur(self,password):
         if password=="@Lun566":
             
             print(f" Sal of {self.name} is {self.__insur}")
         
         else:
             print("Get Lost")
# Out:
#   File <string>:29
#     def inc_sal(self,password):
#                                ^
# IndentationError: unindent does not match any outer indentation level

# %%
EMP_HW_1=Hardware_emp("soni",112,"CEO",300000,"Moon",10,5000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[456], line 1
# ----> 1 EMP_HW_1=Hardware_emp("soni",112,"CEO",300000,"Moon",10,5000)
#
# NameError: name 'Hardware_emp' is not defined

# %%
EMP_HW_1.show_insur(@Lun566")
