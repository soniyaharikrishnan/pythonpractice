# %% [markdown]
# # data type

# %%
a=10

# %%
type(10)
# Out:
# int

# %%
b=1.5

# %%
type(b)
# Out:
# float

# %%
type(a<b)
# Out:
# bool

# %%
print("soniya is very kind person")
# Out:
# soniya is very kind person

# %% [markdown]
# # task

# %%
first_name='Soniya'

# %%
last_name='hari'

# %%
first_name=first_name.upper()

# %%
first_name
# Out:
# 'SONIYA'

# %%
first_name.lower()
# Out:
# 'soniya'

# %%
first_name.count("s")
# Out:
# 0

# %%
first_name.count("S")
# Out:
# 1

# %%
first_name,last_name
# Out:
# ('SONIYA', 'hari')

# %%
full_name=first_name+ " " +last_name

# %%
full_name
# Out:
# 'SONIYA hari'

# %%
full_name[3]
# Out:
# 'I'

# %%
full_name[4]
# Out:
# 'Y'

# %%
full_name[0]
# Out:
# 'S'

# %%
full_name[:6]
# Out:
# 'SONIYA'
