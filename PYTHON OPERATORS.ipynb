# %% [markdown]
# ## operators

# %% [markdown]
# ## arithmetic operators

# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %% [markdown]
# ## comparison operators

# %%
a==10
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %% [markdown]
# ## assigment operators

# %%
a=a+b
a
# Out:
# 30

# %%
a
# Out:
# 30

# %%
b
# Out:
# 20

# %%
a+=b

# %%
a
# Out:
# 50

# %% [markdown]
# ## identity operators

# %%
x=["a","b","c"]
y=["a","c"]

# %%
x is y
# Out:
# False

# %% [markdown]
# ## membership operators

# %%
x=["apple", "banana"]

# %%
print("banana"  in x )
# Out:
# False

# %%
print("apple" not in x )
# Out:
# False
